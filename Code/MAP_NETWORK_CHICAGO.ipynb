# %%
# !pip install osmnx
# Out:
# Collecting osmnx
#   Downloading osmnx-1.5.1-py3-none-any.whl (98 kB)
#                                               0.0/98.8 kB ? eta -:--:--
#      ---------------------------------------- 98.8/98.8 kB ? eta 0:00:00
# Collecting geopandas>=0.12 (from osmnx)
#   Downloading geopandas-0.13.2-py3-none-any.whl (1.1 MB)
#                                               0.0/1.1 MB ? eta -:--:--
#      ------------------------------           0.8/1.1 MB 17.4 MB/s eta 0:00:01
#      ---------------------------------------- 1.1/1.1 MB 13.9 MB/s eta 0:00:00
# Collecting networkx>=2.5 (from osmnx)
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#                                               0.0/2.1 MB ? eta -:--:--
#      --------------                           0.8/2.1 MB 24.1 MB/s eta 0:00:01
#      ---------------------------------        1.7/2.1 MB 27.9 MB/s eta 0:00:01
#      ---------------------------------------- 2.1/2.1 MB 21.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in c:\users\divya\appdata\local\programs\python\python311\lib\site-packages (from osmnx) (1.25.0)
# Requirement already satisfied: pandas>=1.1 in c:\users\divya\appdata\local\programs\python\python311\lib\site-packages (from osmnx) (2.0.3)
# Requirement already satisfied: requests>=2.25 in c:\users\divya\appdata\local\programs\python\python311\lib\site-packages (from osmnx) (2.31.0)
# Collecting shapely>=2.0 (from osmnx)
#   Downloading shapely-2.0.1-cp311-cp311-win_amd64.whl (1.4 MB)
#                                               0.0/1.4 MB ? eta -:--:--
#      --------------------------------         1.1/1.4 MB 23.3 MB/s eta 0:00:01
#      ---------------------------------------- 1.4/1.4 MB 21.8 MB/s eta 0:00:00
# Collecting fiona>=1.8.19 (from geopandas>=0.12->osmnx)
#   Downloading Fiona-1.9.4.post1-cp311-cp311-win_amd64.whl (22.7 MB)
#                                               0.0/22.7 MB ? eta -:--:--
#      -                                        1.0/22.7 MB 33.4 MB/s eta 0:00:01
#      --                                       1.7/22.7 MB 21.5 MB/s eta 0:00:01
#      ----                                     2.6/22.7 MB 23.7 MB/s eta 0:00:01
#      -----                                    3.3/22.7 MB 21.2 MB/s eta 0:00:01
#      -------                                  4.3/22.7 MB 22.9 MB/s eta 0:00:01
#      ---------                                5.2/22.7 MB 23.9 MB/s eta 0:00:01
#      -----------                              6.3/22.7 MB 22.3 MB/s eta 0:00:01
#      ------------                             7.0/22.7 MB 22.4 MB/s eta 0:00:01
#      --------------                           7.9/22.7 MB 22.1 MB/s eta 0:00:01
#      --------------                           8.4/22.7 MB 22.3 MB/s eta 0:00:01
#      ----------------                         9.4/22.7 MB 22.3 MB/s eta 0:00:01
#      -----------------                       10.1/22.7 MB 21.6 MB/s eta 0:00:01
#      -------------------                     11.1/22.7 MB 21.1 MB/s eta 0:00:01
#      --------------------                    12.0/22.7 MB 21.1 MB/s eta 0:00:01
#      ----------------------                  12.8/22.7 MB 21.8 MB/s eta 0:00:01
#      -----------------------                 13.6/22.7 MB 21.8 MB/s eta 0:00:01
#      -------------------------               14.6/22.7 MB 21.1 MB/s eta 0:00:01
#      --------------------------              15.7/22.7 MB 21.1 MB/s eta 0:00:01
#      ---------------------------             16.0/22.7 MB 20.5 MB/s eta 0:00:01
#      -----------------------------           16.9/22.7 MB 20.5 MB/s eta 0:00:01
#      ------------------------------          17.8/22.7 MB 21.1 MB/s eta 0:00:01
#      --------------------------------        18.9/22.7 MB 21.8 MB/s eta 0:00:01
#      ---------------------------------       19.7/22.7 MB 20.5 MB/s eta 0:00:01
#      -----------------------------------     20.6/22.7 MB 21.1 MB/s eta 0:00:01
#      ------------------------------------    21.3/22.7 MB 20.5 MB/s eta 0:00:01
#      --------------------------------------  22.3/22.7 MB 21.1 MB/s eta 0:00:01
#      --------------------------------------  22.7/22.7 MB 21.1 MB/s eta 0:00:01
#      --------------------------------------- 22.7/22.7 MB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\divya\appdata\local\programs\python\python311\lib\site-packages (from geopandas>=0.12->osmnx) (23.1)
# Collecting pyproj>=3.0.1 (from geopandas>=0.12->osmnx)
#   Downloading pyproj-3.6.0-cp311-cp311-win_amd64.whl (5.7 MB)
#                                               0.0/5.7 MB ? eta -:--:--
#      -------                                  1.0/5.7 MB 64.6 MB/s eta 0:00:01
#      --------------                           2.1/5.7 MB 26.7 MB/s eta 0:00:01
#      ---------------------                    3.0/5.7 MB 24.2 MB/s eta 0:00:01
#      ----------------------------             4.1/5.7 MB 26.5 MB/s eta 0:00:01
#      ----------------------------------       5.0/5.7 MB 26.4 MB/s eta 0:00:01
#      ---------------------------------------  5.7/5.7 MB 24.4 MB/s eta 0:00:01
#      ---------------------------------------- 5.7/5.7 MB 21.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\divya\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.1->osmnx) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\divya\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.1->osmnx) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\divya\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.1->osmnx) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\divya\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.25->osmnx) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\divya\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.25->osmnx) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\divya\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.25->osmnx) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\divya\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.25->osmnx) (2023.5.7)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\divya\appdata\local\programs\python\python311\lib\site-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (23.1.0)
# Collecting click~=8.0 (from fiona>=1.8.19->geopandas>=0.12->osmnx)
#   Downloading click-8.1.5-py3-none-any.whl (98 kB)
#                                               0.0/98.1 kB ? eta -:--:--
#      ---------------------------------------- 98.1/98.1 kB 5.5 MB/s eta 0:00:00
# Collecting click-plugins>=1.0 (from fiona>=1.8.19->geopandas>=0.12->osmnx)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5 (from fiona>=1.8.19->geopandas>=0.12->osmnx)
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: six in c:\users\divya\appdata\local\programs\python\python311\lib\site-packages (from fiona>=1.8.19->geopandas>=0.12->osmnx) (1.16.0)
# Requirement already satisfied: colorama in c:\users\divya\appdata\local\programs\python\python311\lib\site-packages (from click~=8.0->fiona>=1.8.19->geopandas>=0.12->osmnx) (0.4.6)
# Installing collected packages: shapely, pyproj, networkx, click, cligj, click-plugins, fiona, geopandas, osmnx
# Successfully installed click-8.1.5 click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.4.post1 geopandas-0.13.2 networkx-3.1 osmnx-1.5.1 pyproj-3.6.0 shapely-2.0.1
# [notice] A new release of pip is available: 23.1.2 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import folium

data=pd.read_json('https://data.cityofchicago.org/resource/t2qc-9pjd.json')
data.head()
# Out:
#                          region  _region_id      _west      _east     _south  \
# 0  North Park-Albany-Linconl Sq           3 -87.747456 -87.674590  41.960669
# 1  Midway-Garfield Rdg-Clearing          17 -87.802188 -87.747456  41.764066
# 2               South West Side          18 -87.747456 -87.683730  41.764066
# 3             Edge Water-Uptown           4 -87.674590 -87.646438  41.960669
# 4        Lincoln Park-Lake View           8 -87.674590 -87.619112  41.910561
#
#       _north                                     _description  current_speed  \
# 0  41.997946          Montrose to Devon. Cicero to Ravenswood          24.55
# 1  41.822792                71st to Pershing. Halem to Cicero          35.05
# 2  41.822792              71st to Pershing. Cicero to Western          25.23
# 3  41.997946      Montrose to Devon. Ravenswood to Lake Shore          26.59
# 4  41.960669  North Ave to Montrose. Ravenswood to Lake Shore          28.64
#
#               _last_updt
# 0  2023-07-18 00:20:48.0
# 1  2023-07-18 00:20:49.0
# 2  2023-07-18 00:20:49.0
# 3  2023-07-18 00:20:48.0
# 4  2023-07-18 00:20:49.0

# %%
data['LONGITUDE']=(data['_east']+data['_west'])/2
data['LATITUDE']=(data['_north']+data['_south'])/2

# %%
data=data.drop(columns=['_east','_west','_south','_north','_description'],axis=1)

# %%
data.head()
# Out:
#                          region  _region_id  current_speed  \
# 0  North Park-Albany-Linconl Sq           3          24.55
# 1  Midway-Garfield Rdg-Clearing          17          35.05
# 2               South West Side          18          25.23
# 3             Edge Water-Uptown           4          26.59
# 4        Lincoln Park-Lake View           8          28.64
#
#               _last_updt  LONGITUDE   LATITUDE
# 0  2023-07-18 00:20:48.0 -87.711023  41.979308
# 1  2023-07-18 00:20:49.0 -87.774822  41.793429
# 2  2023-07-18 00:20:49.0 -87.715593  41.793429
# 3  2023-07-18 00:20:48.0 -87.660514  41.979308
# 4  2023-07-18 00:20:49.0 -87.646851  41.935615

# %%
import ipywidgets as widgets
source=widgets.Dropdown(
    options=np.array(data['region']),
    description='Please select the source:',
)
source
# Out:
# Dropdown(description='Please select the source:', options=('North Park-Albany-Linconl Sq', 'Midway-Garfield Rd…

# %%
destination=widgets.Dropdown(
    options=data['region'],
    description='Please select the destination:',
)
destination
# Out:
# Dropdown(description='Please select the destination:', options=('North Park-Albany-Linconl Sq', 'Midway-Garfie…

# %%
s=source.value
d=destination.value

# %%
start=data[data['region']==s].iloc[:,:].values
end=data[data['region']==d].iloc[:,:].values

# %%
import osmnx as ox
import networkx as nx
ox.settings.log_console=True
ox.settings.use_cache=True

# define the start and end locations in latlng
start_latlng = start[0][5],start[0][4]
end_latlng = end[0][5],end[0][4]

# location where you want to find your route
place     = 'Chicago, Illinois, United States'

# find shortest route based on the mode of travel
mode      = 'drive'        # 'drive', 'bike', 'walk'

# find shortest path based on distance or time
optimizer = 'time'        # 'length','time'

# create graph from OSM within the boundaries of some
# geocodable place(s)
graph = ox.graph_from_place(place, network_type = mode)

# find the nearest node to the start location
orig_node = ox.distance.nearest_nodes(graph, start_latlng[1],
                                      start_latlng[0])

# find the nearest node to the end location
dest_node = ox.distance.nearest_nodes(graph, end_latlng[1],
                                      end_latlng[0])
#  find the shortest path
shortest_route = nx.shortest_path(graph,
                                  orig_node,
                                  dest_node,
                                  weight=optimizer)

# %%
shortest_route_map = ox.plot_route_folium(graph, shortest_route,
                                          tiles='openstreetmap')
# Marker class only accepts coordinates in tuple form
start_latlng = (start_latlng[0],start_latlng[1])
end_latlng   = (end_latlng[0],end_latlng[1])
start_marker = folium.Marker(
            location = start_latlng,
            icon = folium.Icon(color='green'))
end_marker = folium.Marker(
            location = end_latlng,
            icon = folium.Icon(color='red'))
# add the circle marker to the map
start_marker.add_to(shortest_route_map)
end_marker.add_to(shortest_route_map)


shortest_route_map
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_13852\2961681559.py:1: UserWarning: The `folium` module has been deprecated and will be removed in a future release. You can generate and explore interactive web maps of graph nodes, edges, and/or routes automatically using GeoPandas.GeoDataFrame.explore instead, for example like: `ox.graph_to_gdfs(G, nodes=False).explore()`. See the OSMnx examples gallery for complete details and demonstrations.
#   shortest_route_map = ox.plot_route_folium(graph, shortest_route,
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7961356d33054ca63d0cb95ab0b5b121 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7961356d33054ca63d0cb95ab0b5b121&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7961356d33054ca63d0cb95ab0b5b121 = L.map(
#                 &quot;map_7961356d33054ca63d0cb95ab0b5b121&quot;,
#                 {
#                     center: [41.934232360139745, -87.71652869289834],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a0f54bbf42715c21aee7fb8cb2a70452 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7961356d33054ca63d0cb95ab0b5b121);
#
#
#             var poly_line_9978c6ab008340269c366253bf9139c7 = L.polyline(
#                 [[41.979382, -87.7112011], [41.9793751, -87.7118289], [41.9793687, -87.7124225]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7961356d33054ca63d0cb95ab0b5b121);
#
#
#             var poly_line_2acfe5cad3ba60498a4cdc432a3cedee = L.polyline(
#                 [[41.9793687, -87.7124225], [41.9775394, -87.7123729]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7961356d33054ca63d0cb95ab0b5b121);
#
#
#             var poly_line_ab67335c0cf86da8d44bb9a9f49d23b2 = L.polyline(
#                 [[41.9775394, -87.7123729], [41.9761516, -87.7123353], [41.9757029, -87.7123335]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7961356d33054ca63d0cb95ab0b5b121);
#
#
#             var poly_line_bd625646a138c145504d12dfe81fb712 = L.polyline(
#                 [[41.9757029, -87.7123335], [41.9756984, -87.7130253], [41.9756968, -87.7131634], [41.9756948, -87.7133431], [41.9756925, -87.7135538]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7961356d33054ca63d0cb95ab0b5b121);
#
#
#             var poly_line_fa2bfbebf8b2982f1f83b712fb1bd865 = L.polyline(
#                 [[41.9756925, -87.7135538], [41.9756137, -87.7135522], [41.9755132, -87.7135502], [41.9753427, -87.7135467], [41.9752414, -87.7135447], [41.9751701, -87.7135432], [41.9738932, -87.7135174]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7961356d33054ca63d0cb95ab0b5b121);
#
#
#             var poly_line_f710cbbb9b8854e8493230778ec1d53b = L.polyline(
#                 [[41.9738932, -87.7135174], [41.9738033, -87.7135156], [41.97284

# %%
threeroutes=ox.distance.k_shortest_paths(graph,orig_node,dest_node,k=3)

# %%
for i in threeroutes:
  print(i)
# Out:
end_marker = folium.Marker(
                  location = end_latlng,
                  icon = folium.Icon(color='red'))
# add the circle marker to the map
start_marker.add_to(shortest_route_map)
end_marker.add_to(shortest_route_map)
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_13852\489108840.py:1: UserWarning: The `folium` module has been deprecated and will be removed in a future release. You can generate and explore interactive web maps of graph nodes, edges, and/or routes automatically using GeoPandas.GeoDataFrame.explore instead, for example like: `ox.graph_to_gdfs(G, nodes=False).explore()`. See the OSMnx examples gallery for complete details and demonstrations.
#   shortest_route_map = ox.plot_route_folium(graph,i,color='red',tiles='openstreetmap')

# %%
shortest_route_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_efe37d7d02392ac7dbff7d87e64f627a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_efe37d7d02392ac7dbff7d87e64f627a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_efe37d7d02392ac7dbff7d87e64f627a = L.map(
#                 &quot;map_efe37d7d02392ac7dbff7d87e64f627a&quot;,
#                 {
#                     center: [41.93136102654749, -87.71302289801133],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a829d95354fb50d582c2515d81717f45 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_efe37d7d02392ac7dbff7d87e64f627a);
#
#
#             var poly_line_41d274b6e016f6c3b4e9935d46892899 = L.polyline(
#                 [[41.979382, -87.7112011], [41.9793751, -87.7118289], [41.9793687, -87.7124225]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_efe37d7d02392ac7dbff7d87e64f627a);
#
#
#             var poly_line_c2c67e37f68c5dc5a8910ef56752390e = L.polyline(
#                 [[41.9793687, -87.7124225], [41.9775394, -87.7123729]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_efe37d7d02392ac7dbff7d87e64f627a);
#
#
#             var poly_line_43c1201fc2303ccb87c4df87e44ee9aa = L.polyline(
#                 [[41.9775394, -87.7123729], [41.9761516, -87.7123353], [41.9757029, -87.7123335]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_efe37d7d02392ac7dbff7d87e64f627a);
#
#
#             var poly_line_b86900730105e34cbdf364b223365df9 = L.polyline(
#                 [[41.9757029, -87.7123335], [41.9756984, -87.7130253], [41.9756968, -87.7131634], [41.9756948, -87.7133431], [41.9756925, -87.7135538]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_efe37d7d02392ac7dbff7d87e64f627a);
#
#
#             var poly_line_e0424fd1f311f6e3936cbe64ef0818d7 = L.polyline(
#                 [[41.9756925, -87.7135538], [41.9756137, -87.7135522], [41.9755132, -87.7135502], [41.9753427, -87.7135467], [41.9752414, -87.7135447], [41.9751701, -87.7135432], [41.9738932, -87.7135174]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_efe37d7d02392ac7dbff7d87e64f627a);
#
#
#             var poly_line_7caa045f54413eb876a6d7453b2f164b = L.polyline(
#                 [[41.9738932, -87.7135174], [41.9738033, -87.7135156], [41.9728466, -87.7134963], [41.9727643, -87.713494

# %%
shortest_route_map = ox.plot_route_folium(graph,j, color='blue',tiles='openstreetmap')

# Marker class only accepts coordinates in tuple form
start_latlng = (start_latlng[0],start_latlng[1])
end_latlng   = (end_latlng[0],end_latlng[1])
start_marker = folium.Marker(
                  location = start_latlng,
                  icon = folium.Icon(color='green'))
end_marker = folium.Marker(
                  location = end_latlng,
                  icon = folium.Icon(color='red'))
# add the circle marker to the map
start_marker.add_to(shortest_route_map)
end_marker.add_to(shortest_route_map)
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_13852\113467535.py:1: UserWarning: The `folium` module has been deprecated and will be removed in a future release. You can generate and explore interactive web maps of graph nodes, edges, and/or routes automatically using GeoPandas.GeoDataFrame.explore instead, for example like: `ox.graph_to_gdfs(G, nodes=False).explore()`. See the OSMnx examples gallery for complete details and demonstrations.
#   shortest_route_map = ox.plot_route_folium(graph,j, color='blue',tiles='openstreetmap')

# %%
shortest_route_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_795883176eaa81d25be68e56cfc9f4ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_795883176eaa81d25be68e56cfc9f4ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_795883176eaa81d25be68e56cfc9f4ec = L.map(
#                 &quot;map_795883176eaa81d25be68e56cfc9f4ec&quot;,
#                 {
#                     center: [41.93140400706179, -87.71306773399449],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fdfd713da91b84f59d6630571331c1dc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_795883176eaa81d25be68e56cfc9f4ec);
#
#
#             var poly_line_efbcd2395a59e400c6abb4d7371b4f0c = L.polyline(
#                 [[41.979382, -87.7112011], [41.9793751, -87.7118289], [41.9793687, -87.7124225]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_795883176eaa81d25be68e56cfc9f4ec);
#
#
#             var poly_line_269f9a5306575870e6977c8ea51d5e4b = L.polyline(
#                 [[41.9793687, -87.7124225], [41.9775394, -87.7123729]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_795883176eaa81d25be68e56cfc9f4ec);
#
#
#             var poly_line_b99cc1bb8ee9bb099ea430e57ed710d6 = L.polyline(
#                 [[41.9775394, -87.7123729], [41.9761516, -87.7123353], [41.9757029, -87.7123335]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_795883176eaa81d25be68e56cfc9f4ec);
#
#
#             var poly_line_218d15c9f6da85e6353c81250f366236 = L.polyline(
#                 [[41.9757029, -87.7123335], [41.9756984, -87.7130253], [41.9756968, -87.7131634], [41.9756948, -87.7133431], [41.9756925, -87.7135538]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_795883176eaa81d25be68e56cfc9f4ec);
#
#
#             var poly_line_14f6c9fdda7d646eb1ea54b9f21cee4a = L.polyline(
#                 [[41.9756925, -87.7135538], [41.9756137, -87.7135522], [41.9755132, -87.7135502], [41.9753427, -87.7135467], [41.9752414, -87.7135447], [41.9751701, -87.7135432], [41.9738932, -87.7135174]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_795883176eaa81d25be68e56cfc9f4ec);
#
#
#             var poly_line_52cb67b1084032662e052eacb46b91c3 = L.polyline(
#                 [[41.9738932, -87.7135174], [41.9738033, -87.7135156], [41.9728466, -87.7134963], [41.9727643,

# %%
shortest_route_map = ox.plot_route_folium(graph,k, color='green',tiles='openstreetmap')

# Marker class only accepts coordinates in tuple form
start_latlng = (start_latlng[0],start_latlng[1])
end_latlng   = (end_latlng[0],end_latlng[1])
start_marker = folium.Marker(
                  location = start_latlng,
                  icon = folium.Icon(color='green'))
end_marker = folium.Marker(
                  location = end_latlng,
                  icon = folium.Icon(color='red'))
# add the circle marker to the map
start_marker.add_to(shortest_route_map)
end_marker.add_to(shortest_route_map)
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_13852\2542294773.py:1: UserWarning: The `folium` module has been deprecated and will be removed in a future release. You can generate and explore interactive web maps of graph nodes, edges, and/or routes automatically using GeoPandas.GeoDataFrame.explore instead, for example like: `ox.graph_to_gdfs(G, nodes=False).explore()`. See the OSMnx examples gallery for complete details and demonstrations.
#   shortest_route_map = ox.plot_route_folium(graph,k, color='green',tiles='openstreetmap')

# %%
shortest_route_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de32e5c3d7737d1fe05a05589c9140e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de32e5c3d7737d1fe05a05589c9140e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de32e5c3d7737d1fe05a05589c9140e8 = L.map(
#                 &quot;map_de32e5c3d7737d1fe05a05589c9140e8&quot;,
#                 {
#                     center: [41.931382300607495, -87.71304541968358],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a08c54d13edf9291d8dda3b972a19a21 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_de32e5c3d7737d1fe05a05589c9140e8);
#
#
#             var poly_line_62acf4d4c51547fa08d23d85af9143c2 = L.polyline(
#                 [[41.979382, -87.7112011], [41.9793751, -87.7118289], [41.9793687, -87.7124225]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_de32e5c3d7737d1fe05a05589c9140e8);
#
#
#             var poly_line_2d94de33c419e4e7977e6199ca4b4c74 = L.polyline(
#                 [[41.9793687, -87.7124225], [41.9775394, -87.7123729]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_de32e5c3d7737d1fe05a05589c9140e8);
#
#
#             var poly_line_62a65fbe00dacb2e4823f603bebcc702 = L.polyline(
#                 [[41.9775394, -87.7123729], [41.9761516, -87.7123353], [41.9757029, -87.7123335]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_de32e5c3d7737d1fe05a05589c9140e8);
#
#
#             var poly_line_0f990f4281154aabad01554bf253ab23 = L.polyline(
#                 [[41.9757029, -87.7123335], [41.9756984, -87.7130253], [41.9756968, -87.7131634], [41.9756948, -87.7133431], [41.9756925, -87.7135538]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_de32e5c3d7737d1fe05a05589c9140e8);
#
#
#             var poly_line_ebd8d6d2fb5104d55afd2640580b9a02 = L.polyline(
#                 [[41.9756925, -87.7135538], [41.9756137, -87.7135522], [41.9755132, -87.7135502], [41.9753427, -87.7135467], [41.9752414, -87.7135447], [41.9751701, -87.7135432], [41.9738932, -87.7135174]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_de32e5c3d7737d1fe05a05589c9140e8);
#
#
#             var poly_line_221d9d843af710ea5417188453193bb2 = L.polyline(
#                 [[41.9738932, -87.7135174], [41.9738033, -87.7135156], [41.9728466, -87.7134963], [4

# %% [markdown]
# ## DJIKSTRA ALGORITHM

# %%
def func(u, v, d):
    node_u_wt = G.nodes[u].get("node_weight", 1)
    node_v_wt = G.nodes[v].get("node_weight", 1)
    edge_wt = d.get("weight", 1)
    return node_u_wt / 2 + node_v_wt / 2 + edge_wt

# %%
G = nx.path_graph(5)
print(nx.dijkstra_path(G, 0, 4))
# Out:
# [0, 1, 2, 3, 4]

# %%
G = nx.MultiDiGraph()
G.add_weighted_edges_from([(1, 2, 0.75), (1, 2, 0.5), (2, 3, 0.5), (1, 3, 1.5)])
nodes = nx.dijkstra_path(G, 1, 3)
edges = nx.utils.pairwise(nodes)
list((u, v, min(G[u][v], key=lambda k: G[u][v][k].get('weight', 1))) for u, v in edges)
# Out:
# [(1, 2, 1), (2, 3, 0)]

# %%
shortest_route=nx.dijkstra_path(graph,orig_node,dest_node)
shortest_route

# %% [markdown]
# ## A * ALGORITHM

# %%
shortest_route=nx.astar_path(graph,orig_node,dest_node)
shortest_route
